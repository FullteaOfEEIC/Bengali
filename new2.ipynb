# %%
import os
import numpy as np
import pandas as pd
import argparse
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.metrics import categorical_accuracy, top_k_categorical_accuracy
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard

from tensorflow.keras import layers as L
import efficientnet.tfkeras as efn

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
def normalize(image):
  # https://github.com/tensorflow/tpu/blob/master/models/official/efficientnet/main.py#L325-L326
  # https://github.com/tensorflow/tpu/blob/master/models/official/efficientnet/efficientnet_builder.py#L31-L32
  image -= tf.constant([0.485 * 255, 0.456 * 255, 0.406 * 255])  # RGB
  image /= tf.constant([0.229 * 255, 0.224 * 255, 0.225 * 255])  # RGB
  return image


def get_model(input_size, backbone='efficientnet-b6', weights='imagenet', tta=False):
  print(f'Using backbone {backbone} and weights {weights}')
  x = L.Input(shape=input_size, name='imgs', dtype='float32')
  y = normalize(x)
  if backbone.startswith('efficientnet'):
    model_fn = getattr(efn, f'EfficientNetB{backbone[-1]}')

  y = model_fn(input_shape=input_size, weights=weights, include_top=False)(y)
  y = L.GlobalAveragePooling2D()(y)
  y = L.Dropout(0.2)(y)
  # 1292 of 1295 are present
  y = L.Dense(1292, activation='softmax')(y)
  model = tf.keras.Model(x, y)

  if tta:
    assert False, 'This does not make sense yet'
    x_flip = tf.reverse(x, [2])  # 'NHWC'
    y_tta = tf.add(model(x), model(x_flip)) / 2.0
    tta_model = tf.keras.Model(x, y_tta)
    return model, tta_model

  return model


def mixup(img_batch, label_batch, batch_size):
  # https://github.com/tensorpack/tensorpack/blob/master/examples/ResNet/cifar10-preact18-mixup.py
  weight = tf.random.uniform([batch_size])
  x_weight = tf.reshape(weight, [batch_size, 1, 1, 1])
  y_weight = tf.reshape(weight, [batch_size, 1])
  index = tf.random.shuffle(tf.range(batch_size, dtype=tf.int32))
  x1, x2 = img_batch, tf.gather(img_batch, index)
  img_batch = x1 * x_weight + x2 * (1. - x_weight)
  y1, y2 = label_batch, tf.gather(label_batch, index)
  label_batch = y1 * y_weight + y2 * (1. - y_weight)
  return img_batch, label_batch


def get_strategy():
  # Detect hardware, return appropriate distribution strategy
  try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection
    print('Running on TPU ', tpu.cluster_spec().as_dict()['worker'])
  except ValueError:
    tpu = None

  if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
  else:
    strategy = tf.distribute.get_strategy()

  print('REPLICAS: ', strategy.num_replicas_in_sync)
  return strategy


def one_hot(image, label):
  label = tf.one_hot(label, 1292)
  return image, label


def read_tfrecords(example, input_size):
  features = {
      'img': tf.io.FixedLenFeature([], tf.string),
      'image_id': tf.io.FixedLenFeature([], tf.int64),
      'grapheme_root': tf.io.FixedLenFeature([], tf.int64),
      'vowel_diacritic': tf.io.FixedLenFeature([], tf.int64),
      'consonant_diacritic': tf.io.FixedLenFeature([], tf.int64),
      'unique_tuple': tf.io.FixedLenFeature([], tf.int64),
  }
  example = tf.io.parse_single_example(example, features)
  img = tf.image.decode_image(example['img'])
  img = tf.reshape(img, input_size + (1, ))
  img = tf.cast(img, tf.float32)
  # grayscale -> RGB
  img = tf.repeat(img, 3, -1)

  # image_id = tf.cast(example['image_id'], tf.int32)
  # grapheme_root = tf.cast(example['grapheme_root'], tf.int32)
  # vowel_diacritic = tf.cast(example['vowel_diacritic'], tf.int32)
  # consonant_diacritic = tf.cast(example['consonant_diacritic'], tf.int32)
  unique_tuple = tf.cast(example['unique_tuple'], tf.int32)
  return img, unique_tuple


def main():
  parser = argparse.ArgumentParser()
  parser.add_argument('--model_id', type=int, default=1)
  parser.add_argument('--seed', type=int, default=123)
  parser.add_argument('--lr', type=float, default=2e-4)
  parser.add_argument('--input_size', type=str, default='160,256')
  parser.add_argument('--batch_size', type=int, default=32)
  parser.add_argument('--epochs', type=int, default=60)
  parser.add_argument('--backbone', type=str, default='efficientnet-b7')
  parser.add_argument('--weights', type=str, default='imagenet')
  args, _ = parser.parse_known_args()

  args.input_size = tuple(int(x) for x in args.input_size.split(','))
  np.random.seed(args.seed)
  tf.random.set_seed(args.seed)

  # build the model
  strategy = get_strategy()
  with strategy.scope():
    model = get_model(input_size=args.input_size + (3, ), backbone=args.backbone,
        weights=args.weights)

  model.compile(optimizer=Adam(lr=args.lr),
                loss=categorical_crossentropy,
                metrics=[categorical_accuracy, top_k_categorical_accuracy])
  # print(model.summary())
  AUTO = tf.data.experimental.AUTOTUNE
  # create the training and validation datasets
  train_fns = tf.io.gfile.glob('./records/train*.tfrec')
  train_ds = tf.data.TFRecordDataset(train_fns, num_parallel_reads=AUTO)
  train_ds = train_ds.map(lambda e: read_tfrecords(e, args.input_size), num_parallel_calls=AUTO)
  train_ds = train_ds.repeat().batch(args.batch_size)
  train_ds = train_ds.map(one_hot, num_parallel_calls=AUTO)
  train_ds = train_ds.map(lambda a, b: mixup(a, b, args.batch_size), num_parallel_calls=AUTO)

  val_fns = tf.io.gfile.glob('./records/val*.tfrec')
  val_ds = tf.data.TFRecordDataset(val_fns, num_parallel_reads=AUTO)
  val_ds = val_ds.map(lambda e: read_tfrecords(e, args.input_size), num_parallel_calls=AUTO)
  val_ds = val_ds.batch(args.batch_size)
  val_ds = val_ds.map(one_hot, num_parallel_calls=AUTO)

  # train
  num_train_samples = sum(int(fn.split('_')[2]) for fn in train_fns)
  # num_val_samples = sum(int(fn.split('_')[2]) for fn in val_fns)
  steps_per_epoch = num_train_samples // args.batch_size
  print(f'Training on {num_train_samples} samples. Each epochs requires {steps_per_epoch} steps')
  checkpoint = ModelCheckpoint(filepath="tmp-effb7-reborn-epoch{epoch:04}.h5")
  schedule = ReduceLROnPlateau(patience=5,verbose=1)
  h = model.fit(train_ds, steps_per_epoch=steps_per_epoch, epochs=args.epochs, verbose=1,
      validation_data=val_ds,callbacks=[checkpoint,schedule])
  print(h)
  model.save("B7-60.h5",include_optimizer=False)
  return model

# %%
model=main()
# Out:
# REPLICAS:  1
# Using backbone efficientnet-b7 and weights imagenet
# WARNING:tensorflow:Large dropout rate: 0.5125 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.525 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.5375 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.55 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.5625 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Training on 160672 samples. Each epochs requires 5021 steps
# Train for 5021 steps
# Epoch 1/60
# 5021/5021 [==============================] - 3296s 657ms/step - loss: 3.8841 - categorical_accuracy: 0.4736 - top_k_categorical_accuracy: 0.6652 - val_loss: 0.2850 - val_categorical_accuracy: 0.9311 - val_top_k_categorical_accuracy: 0.9918
# Epoch 2/60
# 5021/5021 [==============================] - 3270s 651ms/step - loss: 2.0814 - categorical_accuracy: 0.7416 - top_k_categorical_accuracy: 0.9174 - val_loss: 0.1878 - val_categorical_accuracy: 0.9574 - val_top_k_categorical_accuracy: 0.9951
# Epoch 3/60
# 5021/5021 [==============================] - 3268s 651ms/step - loss: 1.6410 - categorical_accuracy: 0.7592 - top_k_categorical_accuracy: 0.9444 - val_loss: 0.1400 - val_categorical_accuracy: 0.9660 - val_top_k_categorical_accuracy: 0.9968
# Epoch 4/60
# 5021/5021 [==============================] - 3265s 650ms/step - loss: 1.4312 - categorical_accuracy: 0.7689 - top_k_categorical_accuracy: 0.9591 - val_loss: 0.1206 - val_categorical_accuracy: 0.9688 - val_top_k_categorical_accuracy: 0.9971
# Epoch 5/60
# 5021/5021 [==============================] - 3268s 651ms/step - loss: 1.3079 - categorical_accuracy: 0.7744 - top_k_categorical_accuracy: 0.9685 - val_loss: 0.1106 - val_categorical_accuracy: 0.9714 - val_top_k_categorical_accuracy: 0.9976
# Epoch 6/60
# 5021/5021 [==============================] - 3268s 651ms/step - loss: 1.2226 - categorical_accuracy: 0.7818 - top_k_categorical_accuracy: 0.9746 - val_loss: 0.1080 - val_categorical_accuracy: 0.9723 - val_top_k_categorical_accuracy: 0.9979
# Epoch 7/60
# 5021/5021 [==============================] - 3267s 651ms/step - loss: 1.1578 - categorical_accuracy: 0.7880 - top_k_categorical_accuracy: 0.9785 - val_loss: 0.1000 - val_categorical_accuracy: 0.9743 - val_top_k_categorical_accuracy: 0.9978
# Epoch 8/60
# 5021/5021 [==============================] - 3267s 651ms/step - loss: 1.1083 - categorical_accuracy: 0.7906 - top_k_categorical_accuracy: 0.9811 - val_loss: 0.1011 - val_categorical_accuracy: 0.9741 - val_top_k_categorical_accuracy: 0.9978
# Epoch 9/60
# 5021/5021 [==============================] - 3265s 650ms/step - loss: 1.0666 - categorical_accuracy: 0.7922 - top_k_categorical_accuracy: 0.9841 - val_loss: 0.0952 - val_categorical_accuracy: 0.9756 - val_top_k_categorical_accuracy: 0.9979
# Epoch 10/60
# 5021/5021 [==============================] - 3268s 651ms/step - loss: 1.0308 - categorical_accuracy: 0.7956 - top_k_categorical_accuracy: 0.9857 - val_loss: 0.0997 - val_categorical_accuracy: 0.9746 - val_top_k_categorical_accuracy: 0.9977
# Epoch 11/60
# 5021/5021 [==============================] - 3269s 651ms/step - loss: 1.0002 - categorical_accuracy: 0.7991 - top_k_categorical_accuracy: 0.9875 - val_loss: 0.0971 - val_categorical_accuracy: 0.9746 - val_top_k_categorical_accuracy: 0.9979
# Epoch 12/60
# 5021/5021 [==============================] - 3268s 651ms/step - loss: 0.9740 - categorical_accuracy: 0.8027 - top_k_categorical_accuracy: 0.9885 - val_loss: 0.0993 - val_categorical_accuracy: 0.9752 - val_top_k_categorical_accuracy: 0.9976
# Epoch 13/60
# 5021/5021 [==============================] - 3268s 651ms/step - loss: 0.9483 - categorical_accuracy: 0.8038 - top_k_categorical_accuracy: 0.9898 - val_loss: 0.1024 - val_categorical_accuracy: 0.9744 - val_top_k_categorical_accuracy: 0.9976
# Epoch 14/60
# 5020/5021 [============================>.] - ETA: 0s - loss: 0.9245 - categorical_accuracy: 0.8061 - top_k_categorical_accuracy: 0.9911
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 5021/5021 [==============================] - 3265s 650ms/step - loss: 0.9246 - categorical_accuracy: 0.8061 - top_k_categorical_accuracy: 0.9911 - val_loss: 0.1016 - val_categorical_accuracy: 0.9738 - val_top_k_categorical_accuracy: 0.9977
# Epoch 15/60
# 5021/5021 [==============================] - 3268s 651ms/step - loss: 0.8291 - categorical_accuracy: 0.8210 - top_k_categorical_accuracy: 0.9943 - val_loss: 0.0735 - val_categorical_accuracy: 0.9806 - val_top_k_categorical_accuracy: 0.9983
# Epoch 16/60
# 5021/5021 [==============================] - 3267s 651ms/step - loss: 0.7937 - categorical_accuracy: 0.8255 - top_k_categorical_accuracy: 0.9952 - val_loss: 0.0730 - val_categorical_accuracy: 0.9809 - val_top_k_categorical_accuracy: 0.9985
# Epoch 17/60
# 5021/5021 [==============================] - 3268s 651ms/step - loss: 0.7790 - categorical_accuracy: 0.8295 - top_k_categorical_accuracy: 0.9956 - val_loss: 0.0707 - val_categorical_accuracy: 0.9816 - val_top_k_categorical_accuracy: 0.9986
# Epoch 18/60
# 5021/5021 [==============================] - 3268s 651ms/step - loss: 0.7663 - categorical_accuracy: 0.8315 - top_k_categorical_accuracy: 0.9965 - val_loss: 0.0692 - val_categorical_accuracy: 0.9821 - val_top_k_categorical_accuracy: 0.9987
# Epoch 19/60
# 5021/5021 [==============================] - 3265s 650ms/step - loss: 0.7550 - categorical_accuracy: 0.8333 - top_k_categorical_accuracy: 0.9962 - val_loss: 0.0701 - val_categorical_accuracy: 0.9815 - val_top_k_categorical_accuracy: 0.9987
# Epoch 20/60
# 5021/5021 [==============================] - 3268s 651ms/step - loss: 0.7480 - categorical_accuracy: 0.8347 - top_k_categorical_accuracy: 0.9966 - val_loss: 0.0692 - val_categorical_accuracy: 0.9824 - val_top_k_categorical_accuracy: 0.9987
# Epoch 21/60
# 5021/5021 [==============================] - 3267s 651ms/step - loss: 0.7432 - categorical_accuracy: 0.8357 - top_k_categorical_accuracy: 0.9965 - val_loss: 0.0690 - val_categorical_accuracy: 0.9822 - val_top_k_categorical_accuracy: 0.9988
# Epoch 22/60
#  546/5021 [==>...........................] - ETA: 46:10 - loss: 0.7469 - categorical_accuracy: 0.8345 - top_k_categorical_accuracy: 0.9965
