# %%
import os
import numpy as np
import pandas as pd
import argparse
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.metrics import categorical_accuracy, top_k_categorical_accuracy
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard

from tensorflow.keras import layers as L
import efficientnet.tfkeras as efn

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
def normalize(image):
  # https://github.com/tensorflow/tpu/blob/master/models/official/efficientnet/main.py#L325-L326
  # https://github.com/tensorflow/tpu/blob/master/models/official/efficientnet/efficientnet_builder.py#L31-L32
  image -= tf.constant([0.485 * 255, 0.456 * 255, 0.406 * 255])  # RGB
  image /= tf.constant([0.229 * 255, 0.224 * 255, 0.225 * 255])  # RGB
  return image


def get_model(input_size, backbone='efficientnet-b6', weights='imagenet', tta=False):
  print(f'Using backbone {backbone} and weights {weights}')
  x = L.Input(shape=input_size, name='imgs', dtype='float32')
  y = normalize(x)
  if backbone.startswith('efficientnet'):
    model_fn = getattr(efn, f'EfficientNetB{backbone[-1]}')

  y = model_fn(input_shape=input_size, weights=weights, include_top=False)(y)
  y = L.GlobalAveragePooling2D()(y)
  y = L.Dropout(0.2)(y)
  # 1292 of 1295 are present
  y = L.Dense(1292, activation='softmax')(y)
  model = tf.keras.Model(x, y)

  if tta:
    assert False, 'This does not make sense yet'
    x_flip = tf.reverse(x, [2])  # 'NHWC'
    y_tta = tf.add(model(x), model(x_flip)) / 2.0
    tta_model = tf.keras.Model(x, y_tta)
    return model, tta_model

  return model


def mixup(img_batch, label_batch, batch_size):
  # https://github.com/tensorpack/tensorpack/blob/master/examples/ResNet/cifar10-preact18-mixup.py
  weight = tf.random.uniform([batch_size])
  x_weight = tf.reshape(weight, [batch_size, 1, 1, 1])
  y_weight = tf.reshape(weight, [batch_size, 1])
  index = tf.random.shuffle(tf.range(batch_size, dtype=tf.int32))
  x1, x2 = img_batch, tf.gather(img_batch, index)
  img_batch = x1 * x_weight + x2 * (1. - x_weight)
  y1, y2 = label_batch, tf.gather(label_batch, index)
  label_batch = y1 * y_weight + y2 * (1. - y_weight)
  return img_batch, label_batch


def get_strategy():
  # Detect hardware, return appropriate distribution strategy
  try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection
    print('Running on TPU ', tpu.cluster_spec().as_dict()['worker'])
  except ValueError:
    tpu = None

  if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
  else:
    strategy = tf.distribute.get_strategy()

  print('REPLICAS: ', strategy.num_replicas_in_sync)
  return strategy


def one_hot(image, label):
  label = tf.one_hot(label, 1292)
  return image, label


def read_tfrecords(example, input_size):
  features = {
      'img': tf.io.FixedLenFeature([], tf.string),
      'image_id': tf.io.FixedLenFeature([], tf.int64),
      'grapheme_root': tf.io.FixedLenFeature([], tf.int64),
      'vowel_diacritic': tf.io.FixedLenFeature([], tf.int64),
      'consonant_diacritic': tf.io.FixedLenFeature([], tf.int64),
      'unique_tuple': tf.io.FixedLenFeature([], tf.int64),
  }
  example = tf.io.parse_single_example(example, features)
  img = tf.image.decode_image(example['img'])
  img = tf.reshape(img, input_size + (1, ))
  img = tf.cast(img, tf.float32)
  # grayscale -> RGB
  img = tf.repeat(img, 3, -1)

  # image_id = tf.cast(example['image_id'], tf.int32)
  # grapheme_root = tf.cast(example['grapheme_root'], tf.int32)
  # vowel_diacritic = tf.cast(example['vowel_diacritic'], tf.int32)
  # consonant_diacritic = tf.cast(example['consonant_diacritic'], tf.int32)
  unique_tuple = tf.cast(example['unique_tuple'], tf.int32)
  return img, unique_tuple


def main():
  parser = argparse.ArgumentParser()
  parser.add_argument('--model_id', type=int, default=1)
  parser.add_argument('--seed', type=int, default=123)
  parser.add_argument('--lr', type=float, default=2e-4)
  parser.add_argument('--input_size', type=str, default='160,256')
  parser.add_argument('--batch_size', type=int, default=32)
  parser.add_argument('--epochs', type=int, default=60)
  parser.add_argument('--backbone', type=str, default='efficientnet-b6')
  parser.add_argument('--weights', type=str, default='imagenet')
  args, _ = parser.parse_known_args()

  args.input_size = tuple(int(x) for x in args.input_size.split(','))
  np.random.seed(args.seed)
  tf.random.set_seed(args.seed)

  # build the model
  strategy = get_strategy()
  with strategy.scope():
    model = get_model(input_size=args.input_size + (3, ), backbone=args.backbone,
        weights=args.weights)

  model.compile(optimizer=Adam(lr=args.lr),
                loss=categorical_crossentropy,
                metrics=[categorical_accuracy, top_k_categorical_accuracy])
  # print(model.summary())
  AUTO = tf.data.experimental.AUTOTUNE
  # create the training and validation datasets
  train_fns = tf.io.gfile.glob('./records/train*.tfrec')
  train_ds = tf.data.TFRecordDataset(train_fns, num_parallel_reads=AUTO)
  train_ds = train_ds.map(lambda e: read_tfrecords(e, args.input_size), num_parallel_calls=AUTO)
  train_ds = train_ds.repeat().batch(args.batch_size)
  train_ds = train_ds.map(one_hot, num_parallel_calls=AUTO)
  train_ds = train_ds.map(lambda a, b: mixup(a, b, args.batch_size), num_parallel_calls=AUTO)

  val_fns = tf.io.gfile.glob('./records/val*.tfrec')
  val_ds = tf.data.TFRecordDataset(val_fns, num_parallel_reads=AUTO)
  val_ds = val_ds.map(lambda e: read_tfrecords(e, args.input_size), num_parallel_calls=AUTO)
  val_ds = val_ds.batch(args.batch_size)
  val_ds = val_ds.map(one_hot, num_parallel_calls=AUTO)

  # train
  num_train_samples = sum(int(fn.split('_')[2]) for fn in train_fns)
  # num_val_samples = sum(int(fn.split('_')[2]) for fn in val_fns)
  steps_per_epoch = num_train_samples // args.batch_size
  print(f'Training on {num_train_samples} samples. Each epochs requires {steps_per_epoch} steps')
  checkpoint = ModelCheckpoint(filepath="tmp-effb6-reborn-epoch{epoch:04}.h5")
  schedule = ReduceLROnPlateau(patience=5,verbose=1)
  h = model.fit(train_ds, steps_per_epoch=steps_per_epoch, epochs=args.epochs, verbose=1,
      validation_data=val_ds,callbacks=[checkpoint,schedule])
  print(h)
  model.save("B6-60.h5",include_optimizer=False)
  return model

# %%
model=main()
# Out:
# REPLICAS:  1
# Using backbone efficientnet-b6 and weights imagenet
# WARNING:tensorflow:Large dropout rate: 0.5125 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.5375 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.55 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.5125 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.5375 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Training on 160672 samples. Each epochs requires 5021 steps
# Train for 5021 steps
# Epoch 1/60
# 5021/5021 [==============================] - 2631s 524ms/step - loss: 3.9469 - categorical_accuracy: 0.4647 - top_k_categorical_accuracy: 0.6631 - val_loss: 0.3236 - val_categorical_accuracy: 0.9187 - val_top_k_categorical_accuracy: 0.9888
# Epoch 2/60
#   63/5021 [..............................] - ETA: 41:24 - loss: 2.5356 - categorical_accuracy: 0.7267 - top_k_categorical_accuracy: 0.9018
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 5021/5021 [==============================] - 2636s 525ms/step - loss: 2.1964 - categorical_accuracy: 0.7411 - top_k_categorical_accuracy: 0.9149 - val_loss: 0.2107 - val_categorical_accuracy: 0.9479 - val_top_k_categorical_accuracy: 0.9937
# Epoch 3/60
# 5021/5021 [==============================] - 2649s 528ms/step - loss: 1.7347 - categorical_accuracy: 0.7585 - top_k_categorical_accuracy: 0.9397 - val_loss: 0.1730 - val_categorical_accuracy: 0.9563 - val_top_k_categorical_accuracy: 0.9955
# Epoch 4/60
# 5021/5021 [==============================] - 2643s 526ms/step - loss: 1.5057 - categorical_accuracy: 0.7665 - top_k_categorical_accuracy: 0.9540 - val_loss: 0.1621 - val_categorical_accuracy: 0.9583 - val_top_k_categorical_accuracy: 0.9956
# Epoch 5/60
# 5021/5021 [==============================] - 2652s 528ms/step - loss: 1.3702 - categorical_accuracy: 0.7728 - top_k_categorical_accuracy: 0.9639 - val_loss: 0.1423 - val_categorical_accuracy: 0.9631 - val_top_k_categorical_accuracy: 0.9963
# Epoch 6/60
# 5021/5021 [==============================] - 2635s 525ms/step - loss: 1.2686 - categorical_accuracy: 0.7816 - top_k_categorical_accuracy: 0.9706 - val_loss: 0.1331 - val_categorical_accuracy: 0.9665 - val_top_k_categorical_accuracy: 0.9966
# Epoch 7/60
# 5021/5021 [==============================] - 2645s 527ms/step - loss: 1.1890 - categorical_accuracy: 0.7878 - top_k_categorical_accuracy: 0.9762 - val_loss: 0.1242 - val_categorical_accuracy: 0.9680 - val_top_k_categorical_accuracy: 0.9967
# Epoch 8/60
# 5021/5021 [==============================] - 2644s 527ms/step - loss: 1.1328 - categorical_accuracy: 0.7918 - top_k_categorical_accuracy: 0.9798 - val_loss: 0.1227 - val_categorical_accuracy: 0.9696 - val_top_k_categorical_accuracy: 0.9972
# Epoch 9/60
# 5021/5021 [==============================] - 2641s 526ms/step - loss: 1.0876 - categorical_accuracy: 0.7939 - top_k_categorical_accuracy: 0.9827 - val_loss: 0.1114 - val_categorical_accuracy: 0.9720 - val_top_k_categorical_accuracy: 0.9972
# Epoch 10/60
# 5021/5021 [==============================] - 2643s 526ms/step - loss: 1.0463 - categorical_accuracy: 0.7969 - top_k_categorical_accuracy: 0.9849 - val_loss: 0.1309 - val_categorical_accuracy: 0.9675 - val_top_k_categorical_accuracy: 0.9970
# Epoch 11/60
# 5021/5021 [==============================] - 2642s 526ms/step - loss: 1.0144 - categorical_accuracy: 0.8001 - top_k_categorical_accuracy: 0.9861 - val_loss: 0.1033 - val_categorical_accuracy: 0.9736 - val_top_k_categorical_accuracy: 0.9976
# Epoch 12/60
# 5021/5021 [==============================] - 2643s 526ms/step - loss: 0.9858 - categorical_accuracy: 0.8032 - top_k_categorical_accuracy: 0.9872 - val_loss: 0.1177 - val_categorical_accuracy: 0.9708 - val_top_k_categorical_accuracy: 0.9975
# Epoch 13/60
# 5021/5021 [==============================] - 2643s 526ms/step - loss: 0.9573 - categorical_accuracy: 0.8039 - top_k_categorical_accuracy: 0.9888 - val_loss: 0.1014 - val_categorical_accuracy: 0.9745 - val_top_k_categorical_accuracy: 0.9976
# Epoch 14/60
# 5021/5021 [==============================] - 2632s 524ms/step - loss: 0.9346 - categorical_accuracy: 0.8062 - top_k_categorical_accuracy: 0.9903 - val_loss: 0.1047 - val_categorical_accuracy: 0.9726 - val_top_k_categorical_accuracy: 0.9977
# Epoch 15/60
# 5021/5021 [==============================] - 2643s 526ms/step - loss: 0.9175 - categorical_accuracy: 0.8081 - top_k_categorical_accuracy: 0.9906 - val_loss: 0.1038 - val_categorical_accuracy: 0.9742 - val_top_k_categorical_accuracy: 0.9980
# Epoch 16/60
# 5021/5021 [==============================] - 2634s 525ms/step - loss: 0.8956 - categorical_accuracy: 0.8105 - top_k_categorical_accuracy: 0.9913 - val_loss: 0.0974 - val_categorical_accuracy: 0.9752 - val_top_k_categorical_accuracy: 0.9980
# Epoch 17/60
# 5021/5021 [==============================] - 2634s 525ms/step - loss: 0.8808 - categorical_accuracy: 0.8128 - top_k_categorical_accuracy: 0.9922 - val_loss: 0.1126 - val_categorical_accuracy: 0.9724 - val_top_k_categorical_accuracy: 0.9975
# Epoch 18/60
# 5021/5021 [==============================] - 2633s 524ms/step - loss: 0.8623 - categorical_accuracy: 0.8143 - top_k_categorical_accuracy: 0.9927 - val_loss: 0.1085 - val_categorical_accuracy: 0.9741 - val_top_k_categorical_accuracy: 0.9975
# Epoch 19/60
# 5021/5021 [==============================] - 2634s 525ms/step - loss: 0.8475 - categorical_accuracy: 0.8160 - top_k_categorical_accuracy: 0.9935 - val_loss: 0.0942 - val_categorical_accuracy: 0.9771 - val_top_k_categorical_accuracy: 0.9978
# Epoch 20/60
# 5021/5021 [==============================] - 2635s 525ms/step - loss: 0.8350 - categorical_accuracy: 0.8163 - top_k_categorical_accuracy: 0.9942 - val_loss: 0.1047 - val_categorical_accuracy: 0.9744 - val_top_k_categorical_accuracy: 0.9976
# Epoch 21/60
# 5021/5021 [==============================] - 2651s 528ms/step - loss: 0.8271 - categorical_accuracy: 0.8181 - top_k_categorical_accuracy: 0.9943 - val_loss: 0.0953 - val_categorical_accuracy: 0.9763 - val_top_k_categorical_accuracy: 0.9978
# Epoch 22/60
#  805/5021 [===>..........................] - ETA: 35:08 - loss: 0.8209 - categorical_accuracy: 0.8178 - top_k_categorical_accuracy: 0.9943
